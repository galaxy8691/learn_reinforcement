# %%
#!pip install gymnasium
#!pip install swig
#!pip install gymnasium[box2d]
from IPython import display
# %matplotlib inline
import gymnasium as gym
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import time
import random
#torch.set_default_device('cuda')

# %%
from PIL import Image
import numpy as np
def display_image(imageArray):
    display.display(Image.fromarray(np.array(imageArray),'RGB'),clear=True)

# %%
from collections import namedtuple
Transition  = namedtuple('Transition', ('state','action', 'state_next','reward'))

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.fc1 = nn.Linear(4,512)
        self.fc2 = nn.Linear(512,512)
        self.fc3_adv = nn.Linear(512,2)
        self.fc3_val = nn.Linear(512,1)

    def forward(self,x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        adv = self.fc3_adv(x)
        val = self.fc3_val(x).expand(-1,2)
        x = val + adv - adv.mean(1,keepdim=True).expand(-1,2)
        return x

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
MAX_STEP = 500
NUM_EPISODE = 500
CAPACITY = 10000
BATCH_SIZE = 32
GAMMA = 0.99
TD_ERROR_EPSILON = 0.0001
memory = []
td_memory = []
index = 0
target_count = 100
target_suceess_count = 0

main_model = Net()
main_model.to(device)
target_model = Net()
target_model.to(device)

optimizer = optim.Adam(main_model.parameters(), lr=0.0001)

def get_prioritized_indexs(batch_size):
    sum_absolute_td_error = np.sum(np.abs(td_memory))
    sum_absolute_td_error += TD_ERROR_EPSILON * len(td_memory)
    rand_list = np.random.uniform(0, sum_absolute_td_error, batch_size)
    rand_list = np.sort(rand_list)
    sorted_td_memory = np.sort(np.abs(td_memory))
    sorted_td_memory_index = np.argsort(np.abs(td_memory))
    indexes = []
    idx = 0
    tmp_sum_absolute_td_error = 0
    for rand_num in rand_list:
        while tmp_sum_absolute_td_error < rand_num:
            tmp_sum_absolute_td_error += (abs(sorted_td_memory[idx]) + TD_ERROR_EPSILON)
            idx += 1
        if idx >= len(td_memory):
            idx = len(td_memory) - 1
        indexes.append(sorted_td_memory_index[idx])
    return indexes

# def get_prioritized_indexs(batch_size):
#     #sorted_td_memory = np.sort(np.abs(td_memory))[::-1]
#     sorted_td_memory_index = np.argsort(np.abs(td_memory))[::-1]
#     indexes = []
#     for i in range(batch_size):
#         indexes.append(sorted_td_memory_index[i])
#     return indexes

def push_td_error(td_error):
    if len(td_memory) < CAPACITY:
        td_memory.append(None)
    td_memory[index] = td_error

def push(state, action, state_next, reward):
    if len(memory) < CAPACITY:
        memory.append(None)
    memory[index] = Transition(state,action,state_next, reward)
    

def update_index():
    global index
    index = (index + 1) % CAPACITY

def sample(batch_size):
    return random.sample(memory,batch_size)

def update_td_memory():
    global td_memory
    batch = Transition(*zip(*memory))
    state_batch = torch.cat(batch.state).to(device)
    action_batch = torch.cat(batch.action).to(device)
    reward_batch = torch.cat(batch.reward).to(device)
    non_final_next_states = torch.cat([s for s in batch.state_next if s is not None]).to(device)
    main_model.eval()
    target_model.eval()
    state_action_value = main_model(state_batch).gather(1,action_batch)
    mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.state_next))).to(device) != 0
    nsv = torch.zeros(len(memory)).to(device)
    nsv[mask] = target_model(non_final_next_states).max(1)[0].detach().to(device)
    tds = reward_batch + GAMMA * nsv - state_action_value.squeeze()
    td_memory = tds.detach().numpy().tolist()

def replay():
    if len(memory) < BATCH_SIZE:
        return
    rand = random.random()
    if rand < 0.5:
        indexes = get_prioritized_indexs(BATCH_SIZE)
        transition = [memory[n] for n in indexes]
    else:
        transition = sample(BATCH_SIZE)
    batch = Transition(*zip(*transition))
    state_batch = torch.cat(batch.state).to(device)
    action_batch = torch.cat(batch.action).to(device)
    reward_batch = torch.cat(batch.reward).to(device)
    non_final_next_states = torch.cat([s for s in batch.state_next if s is not None]).to(device)
    main_model.eval()
    target_model.eval()
    state_action_value = main_model(state_batch).gather(1,action_batch)
    mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.state_next))).to(device) != 0
    nsv = torch.zeros(BATCH_SIZE).to(device)
    nsv[mask] = target_model(non_final_next_states).max(1)[0].detach().to(device)
    expected_state_action_values = reward_batch + GAMMA * nsv
    main_model.train()
    loss = F.smooth_l1_loss(state_action_value, expected_state_action_values.unsqueeze(1))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

def update_target_model():
    target_model.load_state_dict(main_model.state_dict())   
    
def reset(env):
      observation = env.reset()[0]
      return observation

def reset_memory():
    global memory, td_memory
    global index
    memory = []
    td_memory = []
    index = 0

def get_action(s,epsilon):
    if np.random.rand() < epsilon:
        action = torch.LongTensor([[random.randrange(2)]]).to(device)
    else:
        main_model.eval()
        with torch.no_grad():
            action = main_model(s).max(1)[1].view(1,1)
    return action

# def Q_learning(s, a, r, s_next, Q, eta, gamma, is_terminated):
#     s = digitize_state(s)
#     s_next = digitize_state(s_next)
#     if is_terminated:
#         Q[s, a] = Q[s, a] + eta * (r- Q[s, a])
#     else:
#         Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next, :]) - Q[s, a])
#     return Q

def run_once(env, initial_observation, epsilon, show=False, train=True):
    global target_count, target_suceess_count
    observation = initial_observation
    s = torch.from_numpy(observation).type(torch.FloatTensor)
    s = torch.unsqueeze(s,0).to(device)
    a = get_action(s, epsilon)
    a_next = a
    count = 0;
  
    while True:
        is_terminated = False
        if show:
            time.sleep(0.01)
            img = env.render()
            display_image(img)
        a = a_next
        #s_a_history[-1][1] = a
        s_next, reward, terminated, truncated, info = env.step(a.item())
        s_next = torch.from_numpy(s_next).type(torch.FloatTensor)
        s_next = torch.unsqueeze(s_next,0).to(device)
        #s_a_history.append([s_next, np.nan])
        if count > target_count:
            r = torch.FloatTensor([1.0])
            a_next = None
            is_terminated = True
            s_next = None
            target_suceess_count += 1
            if target_count <= 900:
                if target_suceess_count > 10:
                    target_count += 100
                    target_suceess_count = 0
                    print("new target is ", target_count)
        elif count < target_count and terminated:
            r = torch.FloatTensor([-1.0])
            a_next = None
            is_terminated = True
            s_next = None
            target_suceess_count = 0
        else:
            r = torch.FloatTensor([0.0])
            a_next = get_action(s_next, epsilon)
        push(s, a, s_next, r)
        push_td_error(0)
        update_index()
        if train:
            
            replay()
            
        if is_terminated:
            if show:
                time.sleep(0.01)
                img = env.render()
                display_image(img)
            if train:
                update_target_model()
                update_td_memory()
            break
        else:
            s = s_next
        count += 1

# %%
# model = nn.Sequential()
# model.add_module('fc1',nn.Linear(4,32))
# model.add_module('relu1',nn.ReLU())
# model.add_module('fc2', nn.Linear(32,32))
# model.add_module('relu2', nn.ReLU())
# model.add_module('fc2', nn.Linear(32,2))

a = []
memory=[]
memory.append(Transition(torch.Tensor([1,2,3,4]).unsqueeze(0),torch.Tensor([0]).unsqueeze(0),torch.Tensor([3,4,2,2]).unsqueeze(0),torch.Tensor([1]).unsqueeze(0)))
memory.append(Transition(torch.Tensor([5,5,7,6]).unsqueeze(0),torch.Tensor([1]).unsqueeze(0),torch.Tensor([7,0,2,0]).unsqueeze(0),torch.Tensor([0]).unsqueeze(0)))
memory.append(Transition(torch.Tensor([6,2,3,4]).unsqueeze(0),torch.Tensor([1]).unsqueeze(0),None,torch.Tensor([0]).unsqueeze(0)))
#memory.append(Transition([6,2,3,4],[1],[3,5,4,2],0))
batch = Transition(*zip(*memory))



state_batch = torch.cat(batch.state)
action_batch = torch.cat(batch.action)
reward_batch = torch.cat(batch.reward)
non_final_next_states = torch.cat([s for s in batch.state_next if s is not None])
state_batch
model.eval()
model(state_batch).gather(1,action_batch.long())
mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.state_next))) != 0
nsv = torch.zeros(3)
nsv[mask] = model(non_final_next_states).max(1)[0].detach()

#model(state_batch[0].unsqueeze(1)).max(1)[1].view(1,1)
get_action(state_batch[0].unsqueeze(0),0).item()
#batch
#torch.cat(batch.reward)
# Out:
# 0

# %%
env = gym.make('CartPole-v1', render_mode='rgb_array')
epsilon = 0.5
is_continue = True
episode = 1
reset_memory()
target_count = 100
target_suceess_count = 0
while is_continue:
    observation = reset(env)
    if episode % 100 == 0:
        print('episode: ' + str(episode))
    epsilon = epsilon / 1.1
    run_once(env, observation, epsilon, show=False)
    episode = episode + 1
    if episode > 1000 or target_count >= 1000:
        break
env.close()
# Out:
# new target is  200
# episode: 100
# new target is  300
# episode: 200
# new target is  400
# d:\miniconda3\envs\ml\Lib\site-packages\gymnasium\envs\classic_control\cartpole.py:180: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   logger.warn(
# episode: 300
# new target is  500
# new target is  600
# new target is  700
# episode: 400
# episode: 500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 13
#      11     print('episode: ' + str(episode))
#      12 epsilon = epsilon / 1.1
# ---> 13 run_once(env, observation, epsilon, show=False)
#      14 episode = episode + 1
#      15 if episode > 1000 or target_count >= 1000:
#
# Cell In[5], line 187, in run_once(env, initial_observation, epsilon, show, train)
#     184 update_index()
#     185 if train:
# --> 187     replay()
#     189 if is_terminated:
#     190     if show:
#
# Cell In[5], line 107, in replay()
#     105 optimizer.zero_grad()
#     106 loss.backward()
# --> 107 optimizer.step()
#
# File d:\miniconda3\envs\ml\Lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File d:\miniconda3\envs\ml\Lib\site-packages\torch\optim\optimizer.py:89, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      87     torch.set_grad_enabled(self.defaults["differentiable"])
#      88     torch._dynamo.graph_break()
# ---> 89     ret = func(self, *args, **kwargs)
#      90 finally:
#      91     torch._dynamo.graph_break()
#
# File d:\miniconda3\envs\ml\Lib\site-packages\torch\optim\adam.py:216, in Adam.step(self, closure)
#     213     state_steps: List[Tensor] = []
#     214     beta1, beta2 = group["betas"]
# --> 216     has_complex = self._init_group(
#     217         group,
#     218         params_with_grad,
#     219         grads,
#     220         exp_avgs,
#     221         exp_avg_sqs,
#     222         max_exp_avg_sqs,
#     223         state_steps,
#     224     )
#     226     adam(
#     227         params_with_grad,
#     228         grads,
#    (...)
#     246         found_inf=getattr(self, "found_inf", None),
#     247     )
#     249 return loss
#
# File d:\miniconda3\envs\ml\Lib\site-packages\torch\optim\adam.py:132, in Adam._init_group(self, group, params_with_grad, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps)
#     130 for p in group["params"]:
#     131     if p.grad is not None:
# --> 132         has_complex |= torch.is_complex(p)
#     133         params_with_grad.append(p)
#     134         if p.grad.is_sparse:
#
# KeyboardInterrupt:

# %%
env = gym.make('CartPole-v1', render_mode='rgb_array')
env.reset()
reset_memory()
observation = reset(env)
run_once(env, observation, 0, show=True, train=False)
# ss = torch.from_numpy(observation).type(torch.FloatTensor)
# ss = torch.unsqueeze(ss,0)
# ss
# Out:
# <PIL.Image.Image image mode=RGB size=600x400>
